# %% [markdown]
# # CIS 9440 - yfinance

# %%
# pip install yfinance==0.1.87

# %%
# pip install --upgrade pandas

# %%
try:
    import yfinance as yf
except:
    print("need to install yfinance")

# %%
import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
DJIA = ['MMM', 'AXP', 'AMGN',
        'AAPL', 'BA', 'CAT',
        'CVX', 'CSCO', 'KO',
        'DIS', 'DOW', 'GS',
        'HD', 'HON', 'IBM',
        'INTC', 'JNJ', 'JPM',
        'MCD', 'MRK', 'MSFT',
        'NKE', 'PG', 'CRM',
        'TRV', 'UNH', 'VZ',
        'V', 'WBA', 'WMT']

# %%
def company_info_df(stocks: list):
    # import time
    import time
    
    # create empty dataframe
    company_info_df = pd.DataFrame()
    
    # loop through stocks in list and retrieve stock information
    for s in stocks:
        
        try:
            # create a ticker object
            ticker = yf.Ticker(s)

            # create a dictionary of company information
            stock_info_dict = {'Company' : ticker.info['shortName'],
                               'Ticker' : s,
                               'Sector' : ticker.info['sector'],
                               'Industry' : ticker.info['industry'],
                               'City' : ticker.info['city'],
                               'State' : ticker.info['state'],
                               'Country' : ticker.info['country'],
                               'Full_Time_Employees' : ticker.info['fullTimeEmployees'],
                               'Total_Revenue' : ticker.info['totalRevenue'],
                               'EBITA' : ticker.info['ebitda'],
                               'Fifty_Two_Week_Change' : ticker.info['52WeekChange']}

            # append dictionary to final dataframe
            company_info_df = company_info_df.append(stock_info_dict,
                                                    ignore_index = True)
            time.sleep(2)

            # print success
            print(f"stock {s} appended to company_info_df, shape of company_info_df: {company_info_df.shape}")
        
        # if the stock retrival fails
        except:
            print(f"stock info retrieval failed: {s}")
        
    return company_info_df

# %%
djia_company_info = company_info_df(stocks = DJIA)
# Out:
# stock MMM appended to company_info_df, shape of company_info_df: (1, 11)
# stock AXP appended to company_info_df, shape of company_info_df: (2, 11)
# stock AMGN appended to company_info_df, shape of company_info_df: (3, 11)
# stock AAPL appended to company_info_df, shape of company_info_df: (4, 11)
# stock BA appended to company_info_df, shape of company_info_df: (5, 11)
# stock CAT appended to company_info_df, shape of company_info_df: (6, 11)
# stock CVX appended to company_info_df, shape of company_info_df: (7, 11)
# stock CSCO appended to company_info_df, shape of company_info_df: (8, 11)
# stock KO appended to company_info_df, shape of company_info_df: (9, 11)
# stock info retrieval failed: DIS
# stock DOW appended to company_info_df, shape of company_info_df: (10, 11)
# stock GS appended to company_info_df, shape of company_info_df: (11, 11)
# stock HD appended to company_info_df, shape of company_info_df: (12, 11)
# stock HON appended to company_info_df, shape of company_info_df: (13, 11)
# stock IBM appended to company_info_df, shape of company_info_df: (14, 11)
# stock INTC appended to company_info_df, shape of company_info_df: (15, 11)
# stock JNJ appended to company_info_df, shape of company_info_df: (16, 11)
# stock JPM appended to company_info_df, shape of company_info_df: (17, 11)
# stock MCD appended to company_info_df, shape of company_info_df: (18, 11)
# stock MRK appended to company_info_df, shape of company_info_df: (19, 11)
# stock MSFT appended to company_info_df, shape of company_info_df: (20, 11)
# stock NKE appended to company_info_df, shape of company_info_df: (21, 11)
# stock PG appended to company_info_df, shape of company_info_df: (22, 11)
# stock CRM appended to company_info_df, shape of company_info_df: (23, 11)
# stock TRV appended to company_info_df, shape of company_info_df: (24, 11)
# stock UNH appended to company_info_df, shape of company_info_df: (25, 11)
# stock VZ appended to company_info_df, shape of company_info_df: (26, 11)
# stock V appended to company_info_df, shape of company_info_df: (27, 11)
# stock WBA appended to company_info_df, shape of company_info_df: (28, 11)
# stock WMT appended to company_info_df, shape of company_info_df: (29, 11)

# %%
djia_company_info
# Out:
#                             Company Ticker                  Sector  \
# 0                        3M Company    MMM             Industrials
# 1          American Express Company    AXP      Financial Services
# 2                        Amgen Inc.   AMGN              Healthcare
# 3                        Apple Inc.   AAPL              Technology
# 4              Boeing Company (The)     BA             Industrials
# 5                 Caterpillar, Inc.    CAT             Industrials
# 6               Chevron Corporation    CVX                  Energy
# 7               Cisco Systems, Inc.   CSCO              Technology
# 8           Coca-Cola Company (The)     KO      Consumer Defensive
# 9                          Dow Inc.    DOW         Basic Materials
# 10  Goldman Sachs Group, Inc. (The)     GS      Financial Services
# 11           Home Depot, Inc. (The)     HD       Consumer Cyclical
# 12     Honeywell International Inc.    HON             Industrials
# 13  International Business Machines    IBM              Technology
# 14                Intel Corporation   INTC              Technology
# 15                Johnson & Johnson    JNJ              Healthcare
# 16            JP Morgan Chase & Co.    JPM      Financial Services
# 17           McDonald's Corporation    MCD       Consumer Cyclical
# 18            Merck & Company, Inc.    MRK              Healthcare
# 19            Microsoft Corporation   MSFT              Technology
# 20                       Nike, Inc.    NKE       Consumer Cyclical
# 21   Procter & Gamble Company (The)     PG      Consumer Defensive
# 22                 Salesforce, Inc.    CRM              Technology
# 23    The Travelers Companies, Inc.    TRV      Financial Services
# 24  UnitedHealth Group Incorporated    UNH              Healthcare
# 25      Verizon Communications Inc.     VZ  Communication Services
# 26                        Visa Inc.      V      Financial Services
# 27   Walgreens Boots Alliance, Inc.    WBA              Healthcare
# 28                     Walmart Inc.    WMT      Consumer Defensive
#
#                                Industry           City State        Country  \
# 0                         Conglomerates     Saint Paul    MN  United States
# 1                       Credit Services       New York    NY  United States
# 2            Drug Manufacturers—General  Thousand Oaks    CA  United States
# 3                  Consumer Electronics      Cupertino    CA  United States
# 4                   Aerospace & Defense        Chicago    IL  United States
# 5   Farm & Heavy Construction Machinery         Irving    TX  United States
# 6                  Oil & Gas Integrated      San Ramon    CA  United States
# 7               Communication Equipment       San Jose    CA  United States
# 8               Beverages—Non-Alcoholic        Atlanta    GA  United States
# 9                             Chemicals        Midland    MI  United States
# 10                      Capital Markets       New York    NY  United States
# 11              Home Improvement Retail        Atlanta    GA  United States
# 12                        Conglomerates      Charlotte    NC  United States
# 13      Information Technology Services         Armonk    NY  United States
# 14                       Semiconductors    Santa Clara    CA  United States
# 15           Drug Manufacturers—General  New Brunswick    NJ  United States
# 16                    Banks—Diversified       New York    NY  United States
# 17                          Restaurants        Chicago    IL  United States
# 18           Drug Manufacturers—General     Kenilworth    NJ  United States
# 19              Software—Infrastructure        Redmond    WA  United States
# 20               Footwear & Accessories      Beaverton    OR  United States
# 21        Household & Personal Products     Cincinnati    OH  United States
# 22                 Software—Application  San Francisco    CA  United States
# 23        Insurance—Property & Casualty       New York    NY  United States
# 24                     Healthcare Plans     Minnetonka    MN  United States
# 25                     Telecom Services       New York    NY  United States
# 26                      Credit Services  San Francisco    CA  United States
# 27             Pharmaceutical Retailers      Deerfield    IL  United States
# 28                      Discount Stores    Bentonville    AR  United States
#
#     Full_Time_Employees  Total_Revenue         EBITA  Fifty_Two_Week_Change
# 0               95000.0   3.476200e+10  6968999936.0              -0.276023
# 1               64000.0   4.962300e+10          None              -0.099237
# 2               24200.0   2.633000e+10   13425000448               0.407315
# 3              164000.0   3.943280e+11  130541002752              -0.072620
# 4              142000.0   6.142100e+10   -2680999936              -0.180912
# 5              107700.0   5.662800e+10   11150999552               0.145796
# 6               42595.0   2.270550e+11   52928999424               0.586228
# 7               83300.0   5.228900e+10   15879999488              -0.128916
# 8               79000.0   4.234300e+10   13530999808               0.124842
# 9               35700.0   5.940700e+10    9957999616              -0.120416
# 10              49100.0   4.732400e+10          None              -0.038378
# 11             500000.0   1.572910e+11   27324000256              -0.211667
# 12              99000.0   3.493700e+10    8498999808               0.030866
# 13             282100.0   6.053500e+10   12010000384               0.277307
# 14             121100.0   6.954000e+10   20846000128              -0.400723
# 15             141700.0   9.604100e+10   32049000448               0.103470
# 16             288474.0   1.205850e+11          None              -0.191184
# 17             100000.0   2.326520e+10   12056000512               0.068648
# 18              67000.0   5.897400e+10   24074000384               0.299222
# 19             221000.0   2.030750e+11   98841001984              -0.274866
# 20              79100.0   4.714900e+10    7078000128              -0.384003
# 21             106000.0   8.046100e+10   21364000768              -0.020449
# 22              78634.0   2.932000e+10    2464999936              -0.483868
# 23              30184.0   3.625900e+10    5215000064               0.177140
# 24             350000.0   3.151180e+11   29351000064               0.162009
# 25             119500.0   1.356510e+11   43437998080              -0.241192
# 26              26500.0   2.931000e+10   20596000768               0.034834
# 27             200000.0   1.327030e+11    4749000192              -0.103604
# 28            2300000.0   6.001120e+11   31594000384               0.035144

# %%
djia_company_info.to_csv("djia.csv", index = False)

# %%
def create_stock_df(ticker: str,
                    start: str,
                    end: str,
                    SMA: int):
    
    # get the data from yahoo finance
    df = yf.download(ticker, 
                     start=start, 
                     end=end)
    
    # add extra columns for day, ticker,
    # simple moving average, and closing price average difference
    df['day'] = range(1, len(df) + 1)
    df['ticker'] = ticker
    SMA_name = f"SMA_{str(SMA)}" 
    df[SMA_name] = df.iloc[:,4].rolling(window=SMA).mean()
    
    # reset the index
    df = df.reset_index()
    
    # return the dataframe
    return df

# %%
def plot_stock_price(df):
    
    x = df['Date']
    y = df['Close']
    ticker_name = df['ticker'][0]

    # plotting the points  
    plt.plot(x, y) 

    # naming the axes 
    plt.xlabel('date')
    plt.ylabel('price/share')

    # rotate the tick marks
    plt.xticks(rotation=70)

    # title
    plt.title('Stock Price over time: '+str(ticker_name)) 

    # function to show the plot 
    plt.show()

# %%
for c in []:
    df = create_stock_df(c, start = '2013-01-01',
                         end = '2021-02-01', SMA = 20)
    plot_stock_price(df)
